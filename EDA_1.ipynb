# %% [markdown]
# # Alexine Studios

# %% [markdown]
# ## Download Dataset

# %%
# !mkdir datasets
# !wget -qq https://github.com/chiruharshith/Alexine_Studios/blob/main/datasets/weather_data.zip
# !unzip weather_data.zip

# %%
# Importing all the required packages
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Read the Weather data of all the years provided
w_2009 = pd.read_csv('datasets/weather_data/weather_data_2009.csv')
w_2010 = pd.read_csv('datasets/weather_data/weather_data_2010.csv')
w_2011 = pd.read_csv('datasets/weather_data/weather_data_2011.csv')
w_2012 = pd.read_csv('datasets/weather_data/weather_data_2012.csv')
w_2013 = pd.read_csv('datasets/weather_data/weather_data_2013.csv')
w_2014 = pd.read_csv('datasets/weather_data/weather_data_2014.csv')
w_2015 = pd.read_csv('datasets/weather_data/weather_data_2015.csv')
w_2016 = pd.read_csv('datasets/weather_data/weather_data_2016.csv')

# %%
w_2009.head(2)
# Out:
#    Year Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 0  2009   Jan    1              -3             -9                  -16
# 1  2009   Jan    2               1             -5                   -3
#
#    Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 0                 -19                 54                32
# 1                 -17                 78                36
#
#    Sea Level Press. (hPa) high  Sea Level Press. (hPa) low  \
# 0                         1025                        1015
# 1                         1022                        1007
#
#    Visibility (km) high  Visibility (km) low Wind (km/h) low Wind (km/h) high  \
# 0                    16                   16              37               60
# 1                    16                    2              27               48
#
#   Precip. (mm) sum WeatherEvent
# 0                0          NaN
# 1                T         Snow

# %%
w_2010.head(2)
# Out:
#    Year Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 0  2010   Jan    1               4              1                    1
# 1  2010   Jan    2               1             -8                   -4
#
#    Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 0                  -3                100                70
# 1                 -16                 85                50
#
#    Sea Level Press. (hPa) high  Sea Level Press. (hPa) low  \
# 0                         1016                        1006
# 1                         1006                        1003
#
#    Visibility (km) high  Visibility (km) low  Wind (km/h) low  \
# 0                    16                    3               26
# 1                    16                    2               35
#
#   Wind (km/h) high Precip. (mm) sum WeatherEvent
# 0               35             0.76         Snow
# 1               56             0.51         Snow

# %%
w_2011.head(2)
# Out:
#    Year Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 0  2011   Jan    1              12              4                    8
# 1  2011   Jan    2              11              2                    9
#
#    Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 0                  -2                 83                50
# 1                  -7                100                45
#
#    Sea Level Press. (hPa) high  Sea Level Press. (hPa) low  \
# 0                         1021                        1015
# 1                         1015                        1011
#
#    Visibility (km) high  Visibility (km) low  Wind (km/h) low  \
# 0                    11                    8               19
# 1                    16                    1               32
#
#   Wind (km/h) high Precip. (mm) sum WeatherEvent
# 0               26                0          NaN
# 1               45             0.25   Fog , Rain

# %%
w_2012.head(2)
# Out:
#    Year Month  Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 0  2012   Jan    1             11             5                   8
# 1  2012   Jan    2             10             1                   4
#
#   Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 0                  3                82               59
# 1                 -9                74               37
#
#   Sea Level Press. (hPa) high Sea Level Press. (hPa) low Visibility (km) high  \
# 0                        1020                       1005                   16
# 1                        1010                       1005                   16
#
#   Visibility (km) low Wind (km/h) low Wind (km/h) high Precip. (mm) sum  \
# 0                  10              24               35             1.27
# 1                  16              40               52                0
#
#   WeatherEvent
# 0         Rain
# 1          NaN

# %%
w_2013.head(2)
# Out:
#    Year Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 0  2013   Jan    1               4             -3                   -3
# 1  2013   Jan    2               1             -6                   -9
#
#    Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 0                 -13                 64                44
# 1                 -13                 57                39
#
#    Sea Level Press. (hPa) high  Sea Level Press. (hPa) low  \
# 0                         1016                        1010
# 1                         1022                        1016
#
#    Visibility (km) high  Visibility (km) low  Wind (km/h) low  \
# 0                    16                   16               24
# 1                    16                   16               24
#
#   Wind (km/h) high Precip. (mm) sum WeatherEvent
# 0               42                0          NaN
# 1               35                0          NaN

# %%
w_2013.tail(2)
# Out:
#      Year Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 363  2013   Dec   30               7             -5                    2
# 364  2013   Dec   31               0             -6                   -7
#
#      Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 363                 -14                 76                43
# 364                 -15                 63                38
#
#      Sea Level Press. (hPa) high  Sea Level Press. (hPa) low  \
# 363                         1023                        1006
# 364                         1025                        1018
#
#      Visibility (km) high  Visibility (km) low  Wind (km/h) low  \
# 363                    16                   16               24
# 364                    16                   13               27
#
#     Wind (km/h) high Precip. (mm) sum WeatherEvent
# 363               40                0          NaN
# 364               45                T          NaN

# %%
w_2014.head(2)
# Out:
#      Year Month  Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 0  2014.0   Jan  1.0           high           low                high
# 1  2014.0   Jan  2.0              1            -4                  -7
#
#   Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 0                low              high              low
# 1                -15                59               38
#
#   Sea Level Press. (hPa) high Sea Level Press. (hPa) low Visibility (km) high  \
# 0                        high                        low                 high
# 1                        1029                       1025                   16
#
#   Visibility (km) low Wind (km/h) low Wind (km/h) high Precip. (mm) sum  \
# 0                 low             low             high              sum
# 1                  16              23               37                0
#
#   WeatherEvent
# 0          NaN
# 1          NaN

# %%
w_2014.tail(2)
# Out:
#        Year Month   Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 364  2014.0   Dec  31.0              1            -2                  -8
# 365     NaN   NaN   NaN              0            -3                 -11
#
#     Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 364                -13                58               36
# 365                -15                55               30
#
#     Sea Level Press. (hPa) high Sea Level Press. (hPa) low  \
# 364                        1029                       1025
# 365                        1028                       1022
#
#     Visibility (km) high Visibility (km) low Wind (km/h) low Wind (km/h) high  \
# 364                   16                  16              16               27
# 365                   16                  16              23               34
#
#     Precip. (mm) sum WeatherEvent
# 364                0          NaN
# 365                0          NaN

# %%
w_2015.head()
# Out:
#    Year Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 0  2015   Jan    1               4             -3                   -8
# 1  2015   Jan    2               6              2                   -7
# 2  2015   Jan    3               6              1                    4
# 3  2015   Jan    4              13              5                   10
# 4  2015   Jan    5               9             -6                   -3
#
#    Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 0                 -14                 46                27
# 1                  -9                 52                33
# 2                  -9                 92                44
# 3                  -3                 93                83
# 4                 -19                 49                26
#
#   Sea Level Press. (hPa) high Sea Level Press. (hPa) low Visibility (km) high  \
# 0                        1022                       1015                   16
# 1                        1031                       1016                   16
# 2                        1036                       1019                   16
# 3                        1019                       1004                   16
# 4                        1030                       1009                   16
#
#   Visibility (km) low Wind (km/h) low Wind (km/h) high Precip. (mm) sum  \
# 0                  16              27               50                0
# 1                  16              24               40                0
# 2                   1              19               29            18.03
# 3                   1              47               74             7.62
# 4                  16              39               61                0
#
#   WeatherEvent
# 0          NaN
# 1          NaN
# 2  Rain , Snow
# 3         Rain
# 4          NaN

# %%
w_2016.head()
# Out:
#    Year Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 0  2016   Jan    1               6              1                   -3
# 1  2016   Jan    2               4              0                   -7
# 2  2016   Jan    3               7              2                   -5
# 3  2016   Jan    4               2            -10                   -5
# 4  2016   Jan    5              -2            -12                  -17
#
#    Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 0                  -9                 59                44
# 1                  -9                 52                40
# 2                  -7                 56                37
# 3                 -18                 59                28
# 4                 -21                 58                24
#
#   Sea Level Press. (hPa) high Sea Level Press. (hPa) low Visibility (km) high  \
# 0                        1018                       1015                   16
# 1                        1019                       1014                   16
# 2                        1014                       1009                   16
# 3                        1027                       1011                   16
# 4                        1037                       1031                   16
#
#   Visibility (km) low Wind (km/h) low Wind (km/h) high Precip. (mm) sum  \
# 0                  16              27               42                0
# 1                  16              24               37                0
# 2                  16              27               42                0
# 3                  16              34               50                0
# 4                  16              32               48                0
#
#   WeatherEvent
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Verify the size of every column of all sheets and ensure no discrepancy in the data size
# 2014 weather data header has been extended to the 0th row for some of the columns, while values in columns such as Year, Month, and Day were added to the 0th row, leaving empty values in the last row. Shift the cells by 1 in these columns.
w_2014['Year'] = w_2014['Year'].shift(1)

# %%
w_2014.head()
# Out:
#      Year Month  Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 0     NaN   Jan  1.0           high           low                high
# 1  2014.0   Jan  2.0              1            -4                  -7
# 2  2014.0   Jan  3.0              1            -8                  -5
# 3  2014.0   Jan  4.0             -8           -13                 -11
# 4  2014.0   Jan  5.0             -2           -13                  -9
#
#   Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 0                low              high              low
# 1                -15                59               38
# 2                -10                84               56
# 3                -22                84               42
# 4                -21                66               35
#
#   Sea Level Press. (hPa) high Sea Level Press. (hPa) low Visibility (km) high  \
# 0                        high                        low                 high
# 1                        1029                       1025                   16
# 2                        1023                       1005                   16
# 3                        1032                       1004                   16
# 4                        1034                       1026                   16
#
#   Visibility (km) low Wind (km/h) low Wind (km/h) high Precip. (mm) sum  \
# 0                 low             low             high              sum
# 1                  16              23               37                0
# 2                   1              34               45             8.38
# 3                   0              34               47             7.37
# 4                  16              14               32                0
#
#   WeatherEvent
# 0          NaN
# 1          NaN
# 2   Fog , Snow
# 3         Snow
# 4          NaN

# %%
w_2014['Day'] = w_2014['Day'].shift(1)
w_2014['Month'] = w_2014['Month'].shift(1)

# %%
w_2014['Day'].shift(-1)
# Out:
# 0       1.0
# 1       2.0
# 2       3.0
# 3       4.0
# 4       5.0
#        ...
# 361    28.0
# 362    29.0
# 363    30.0
# 364    31.0
# 365     NaN
# Name: Day, Length: 366, dtype: float64

# %%
w_2014.head()
# Out:
#      Year Month  Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 0     NaN   NaN  NaN           high           low                high
# 1  2014.0   Jan  1.0              1            -4                  -7
# 2  2014.0   Jan  2.0              1            -8                  -5
# 3  2014.0   Jan  3.0             -8           -13                 -11
# 4  2014.0   Jan  4.0             -2           -13                  -9
#
#   Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 0                low              high              low
# 1                -15                59               38
# 2                -10                84               56
# 3                -22                84               42
# 4                -21                66               35
#
#   Sea Level Press. (hPa) high Sea Level Press. (hPa) low Visibility (km) high  \
# 0                        high                        low                 high
# 1                        1029                       1025                   16
# 2                        1023                       1005                   16
# 3                        1032                       1004                   16
# 4                        1034                       1026                   16
#
#   Visibility (km) low Wind (km/h) low Wind (km/h) high Precip. (mm) sum  \
# 0                 low             low             high              sum
# 1                  16              23               37                0
# 2                   1              34               45             8.38
# 3                   0              34               47             7.37
# 4                  16              14               32                0
#
#   WeatherEvent
# 0          NaN
# 1          NaN
# 2   Fog , Snow
# 3         Snow
# 4          NaN

# %%
w_2014.drop(w_2014.index[0], inplace=True)

# %%
w_2014
# Out:
#        Year Month   Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 1    2014.0   Jan   1.0              1            -4                  -7
# 2    2014.0   Jan   2.0              1            -8                  -5
# 3    2014.0   Jan   3.0             -8           -13                 -11
# 4    2014.0   Jan   4.0             -2           -13                  -9
# 5    2014.0   Jan   5.0              4            -3                   3
# ..      ...   ...   ...            ...           ...                 ...
# 361  2014.0   Dec  27.0             13             7                   2
# 362  2014.0   Dec  28.0             12             6                   6
# 363  2014.0   Dec  29.0              7             1                  -4
# 364  2014.0   Dec  30.0              1            -2                  -8
# 365  2014.0   Dec  31.0              0            -3                 -11
#
#     Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 1                  -15                59               38
# 2                  -10                84               56
# 3                  -22                84               42
# 4                  -21                66               35
# 5                   -8                92               58
# ..                 ...               ...              ...
# 361                 -2                53               41
# 362                 -3                92               53
# 363                 -9                53               31
# 364                -13                58               36
# 365                -15                55               30
#
#     Sea Level Press. (hPa) high Sea Level Press. (hPa) low  \
# 1                          1029                       1025
# 2                          1023                       1005
# 3                          1032                       1004
# 4                          1034                       1026
# 5                          1027                       1010
# ..                          ...                        ...
# 361                        1025                       1018
# 362                        1018                       1012
# 363                        1025                       1019
# 364                        1029                       1025
# 365                        1028                       1022
#
#     Visibility (km) high Visibility (km) low Wind (km/h) low Wind (km/h) high  \
# 1                     16                  16              23               37
# 2                     16                   1              34               45
# 3                     16                   0              34               47
# 4                     16                  16              14               32
# 5                     16                   0              11               27
# ..                   ...                 ...             ...              ...
# 361                   16                  16              23               40
# 362                   16                   3              24               35
# 363                   16                  16              24               40
# 364                   16                  16              16               27
# 365                   16                  16              23               34
#
#     Precip. (mm) sum WeatherEvent
# 1                  0          NaN
# 2               8.38   Fog , Snow
# 3               7.37         Snow
# 4                  0          NaN
# 5               3.56   Fog , Rain
# ..               ...          ...
# 361                0          NaN
# 362             2.54         Rain
# 363                0          NaN
# 364                0          NaN
# 365                0          NaN
#
# [365 rows x 17 columns]

# %%
w_2009.shape, w_2010.shape, w_2011.shape, w_2012.shape, w_2013.shape, w_2014.shape, w_2015.shape, w_2016.shape
# Out:
# ((386, 17),
#  (365, 17),
#  (365, 17),
#  (366, 17),
#  (365, 17),
#  (365, 17),
#  (365, 17),
#  (366, 17))

# %%
# Combine the Weather data of all the years
total = pd.concat([w_2009,w_2010,w_2011,w_2012,w_2013,w_2014,w_2015,w_2016])
total
# Out:
#        Year Month   Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 0    2009.0   Jan   1.0             -3            -9                 -16
# 1    2009.0   Jan   2.0              1            -5                  -3
# 2    2009.0   Jan   3.0              3            -2                  -5
# 3    2009.0   Jan   4.0              6            -4                 -10
# 4    2009.0   Jan   5.0              6             3                  -1
# ..      ...   ...   ...            ...           ...                 ...
# 361  2016.0   Dec  27.0             16             4                  11
# 362  2016.0   Dec  28.0              4             1                  -3
# 363  2016.0   Dec  29.0              8             1                   7
# 364  2016.0   Dec  30.0              4             1                  -1
# 365  2016.0   Dec  31.0              7            -1                  -3
#
#     Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 0                  -19                54               32
# 1                  -17                78               36
# 2                  -13                72               35
# 3                  -13                55               29
# 4                  -16                62               33
# ..                 ...               ...              ...
# 361                 -3                89               33
# 362                 -7                64               44
# 363                 -7                96               52
# 364                 -7                82               44
# 365                 -9                56               36
#
#     Sea Level Press. (hPa) high Sea Level Press. (hPa) low  \
# 0                          1025                       1015
# 1                          1022                       1007
# 2                          1018                       1008
# 3                          1020                       1015
# 4                          1016                       1013
# ..                          ...                        ...
# 361                        1017                       1008
# 362                        1022                       1014
# 363                        1019                       1000
# 364                        1015                       1000
# 365                        1021                       1012
#
#     Visibility (km) high Visibility (km) low Wind (km/h) low Wind (km/h) high  \
# 0                     16                  16              37               60
# 1                     16                   2              27               48
# 2                     16                  16              27               42
# 3                     16                  16              32               40
# 4                     16                  16              23               34
# ..                   ...                 ...             ...              ...
# 361                   16                  14              32               53
# 362                   16                  16              23               34
# 363                   16                   2              24               40
# 364                   16                   1              29               47
# 365                   16                  16              24               40
#
#     Precip. (mm) sum WeatherEvent
# 0                  0          NaN
# 1                  T         Snow
# 2                  T          NaN
# 3                  0          NaN
# 4                  T          NaN
# ..               ...          ...
# 361                0          NaN
# 362                0          NaN
# 363             9.91         Rain
# 364             0.25   Fog , Snow
# 365                0          NaN
#
# [2943 rows x 17 columns]

# %%
# Group the data by WeatherEvent column 
groups = total.groupby(['WeatherEvent'])
groups.first()
# Out:
#                      Year Month   Day  Temp high (°C)  Temp low (°C)  \
# WeatherEvent
# Fog                2009.0   Mar   2.0              -2             -9
# Fog , Rain         2009.0   Apr   3.0              16              9
# Fog , Rain , Snow  2009.0   Jan  10.0              -1             -5
# Fog , Snow         2009.0   Jan  18.0               2             -6
# Rain               2009.0   Jan   6.0               3             -1
# Rain , Snow        2009.0   Feb  18.0               7              0
# Snow               2009.0   Jan   2.0               1             -5
# Thunderstorm       2011.0   Jul  31.0              33             22
#
#                    Dew Point high (°C)  Dew Point low (°C)  Humidity (%) high  \
# WeatherEvent
# Fog                                 -3                 -17                 96
# Fog , Rain                          14                   7                100
# Fog , Rain , Snow                   -3                 -12                 88
# Fog , Snow                          -1                 -12                100
# Rain                                -2                 -18                 85
# Rain , Snow                          6                  -9                100
# Snow                                -3                 -17                 78
# Thunderstorm                        17                  16                 78
#
#                    Humidity (%) low  Sea Level Press. (hPa) high  \
# WeatherEvent
# Fog                              54                         1019
# Fog , Rain                       60                         1012
# Fog , Rain , Snow                50                         1026
# Fog , Snow                       55                         1025
# Rain                             22                         1019
# Rain , Snow                      47                         1021
# Snow                             36                         1022
# Thunderstorm                     36                         1017
#
#                    Sea Level Press. (hPa) low  Visibility (km) high  \
# WeatherEvent
# Fog                                      1010                    16
# Fog , Rain                                987                    16
# Fog , Rain , Snow                        1012                    16
# Fog , Snow                               1006                    16
# Rain                                     1009                    16
# Rain , Snow                               997                    16
# Snow                                     1007                    16
# Thunderstorm                             1016                    16
#
#                    Visibility (km) low Wind (km/h) low Wind (km/h) high  \
# WeatherEvent
# Fog                                  0              32               52
# Fog , Rain                           0              32               47
# Fog , Rain , Snow                    1              26               39
# Fog , Snow                           1              19               27
# Rain                                 6              24               29
# Rain , Snow                          3              27               40
# Snow                                 2              27               48
# Thunderstorm                        16              16               26
#
#                   Precip. (mm) sum
# WeatherEvent
# Fog                          12.45
# Fog , Rain                   23.11
# Fog , Rain , Snow             3.56
# Fog , Snow                    4.57
# Rain                          2.03
# Rain , Snow                   8.13
# Snow                             T
# Thunderstorm                     T

# %%
total.head(3)
# Out:
#      Year Month  Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 0  2009.0   Jan  1.0             -3            -9                 -16
# 1  2009.0   Jan  2.0              1            -5                  -3
# 2  2009.0   Jan  3.0              3            -2                  -5
#
#   Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 0                -19                54               32
# 1                -17                78               36
# 2                -13                72               35
#
#   Sea Level Press. (hPa) high Sea Level Press. (hPa) low Visibility (km) high  \
# 0                        1025                       1015                   16
# 1                        1022                       1007                   16
# 2                        1018                       1008                   16
#
#   Visibility (km) low Wind (km/h) low Wind (km/h) high Precip. (mm) sum  \
# 0                  16              37               60                0
# 1                   2              27               48                T
# 2                  16              27               42                T
#
#   WeatherEvent
# 0          NaN
# 1         Snow
# 2          NaN

# %%
total['Month']
# Out:
# 0      Jan
# 1      Jan
# 2      Jan
# 3      Jan
# 4      Jan
#       ...
# 361    Dec
# 362    Dec
# 363    Dec
# 364    Dec
# 365    Dec
# Name: Month, Length: 2943, dtype: object

# %%
# Convert the Month and Year to numericals (ex: Jan: 1)
Year = {2009.0: 1, 2010.0:2, 2011.0:3, 2012.0:4, 2013.0:5, 2014.0:6, 2015.0:7, 2016.0:8}
Month = {'Jan':1, 'Feb':2, 'Mar': 3, 'Apr': 4, 'May':5, 'Jun':6, 'Jul':7, 'Aug':8, 'Sep':9, 'Oct':10, 'Nov':11,'Dec':12}

total['Year'] = total['Year'].map(Year)
total['Month'] = total['Month'].map(Month)

# %%
total
# Out:
#      Year  Month   Day Temp high (°C) Temp low (°C) Dew Point high (°C)  \
# 0       1      1   1.0             -3            -9                 -16
# 1       1      1   2.0              1            -5                  -3
# 2       1      1   3.0              3            -2                  -5
# 3       1      1   4.0              6            -4                 -10
# 4       1      1   5.0              6             3                  -1
# ..    ...    ...   ...            ...           ...                 ...
# 361     8     12  27.0             16             4                  11
# 362     8     12  28.0              4             1                  -3
# 363     8     12  29.0              8             1                   7
# 364     8     12  30.0              4             1                  -1
# 365     8     12  31.0              7            -1                  -3
#
#     Dew Point low (°C) Humidity (%) high Humidity (%) low  \
# 0                  -19                54               32
# 1                  -17                78               36
# 2                  -13                72               35
# 3                  -13                55               29
# 4                  -16                62               33
# ..                 ...               ...              ...
# 361                 -3                89               33
# 362                 -7                64               44
# 363                 -7                96               52
# 364                 -7                82               44
# 365                 -9                56               36
#
#     Sea Level Press. (hPa) high Sea Level Press. (hPa) low  \
# 0                          1025                       1015
# 1                          1022                       1007
# 2                          1018                       1008
# 3                          1020                       1015
# 4                          1016                       1013
# ..                          ...                        ...
# 361                        1017                       1008
# 362                        1022                       1014
# 363                        1019                       1000
# 364                        1015                       1000
# 365                        1021                       1012
#
#     Visibility (km) high Visibility (km) low Wind (km/h) low Wind (km/h) high  \
# 0                     16                  16              37               60
# 1                     16                   2              27               48
# 2                     16                  16              27               42
# 3                     16                  16              32               40
# 4                     16                  16              23               34
# ..                   ...                 ...             ...              ...
# 361                   16                  14              32               53
# 362                   16                  16              23               34
# 363                   16                   2              24               40
# 364                   16                   1              29               47
# 365                   16                  16              24               40
#
#     Precip. (mm) sum WeatherEvent
# 0                  0          NaN
# 1                  T         Snow
# 2                  T          NaN
# 3                  0          NaN
# 4                  T          NaN
# ..               ...          ...
# 361                0          NaN
# 362                0          NaN
# 363             9.91         Rain
# 364             0.25   Fog , Snow
# 365                0          NaN
#
# [2943 rows x 17 columns]

# %%
## Except for the "WeatherEvent" column, convert the datatypes of all the columns to "int / float"
required_columns = total.columns[0:-1]

# %%
required_columns
# Out:
# Index(['Year', 'Month', 'Day', 'Temp high (°C)', 'Temp low (°C)',
#        'Dew Point high (°C)', 'Dew Point low (°C)', 'Humidity (%) high',
#        'Humidity (%) low', 'Sea Level Press. (hPa) high',
#        'Sea Level Press. (hPa) low', 'Visibility (km) high',
#        'Visibility (km) low', 'Wind (km/h) low', 'Wind (km/h) high',
#        'Precip. (mm) sum'],
#       dtype='object')

# %%
for each_column_name in required_columns:
    total[each_column_name] = pd.to_numeric(total[each_column_name], errors='coerce')

# %%
total.dtypes
# Out:
# Year                             int64
# Month                            int64
# Day                            float64
# Temp high (°C)                 float64
# Temp low (°C)                  float64
# Dew Point high (°C)            float64
# Dew Point low (°C)             float64
# Humidity (%) high              float64
# Humidity (%) low               float64
# Sea Level Press. (hPa) high    float64
# Sea Level Press. (hPa) low     float64
# Visibility (km) high           float64
# Visibility (km) low            float64
# Wind (km/h) low                float64
# Wind (km/h) high               float64
# Precip. (mm) sum               float64
# WeatherEvent                    object
# dtype: object

# %%
# For each collection of the below-mentioned columns, constructing a new average column with the average of their values and drop the remaining columns
string = "Temp high (C)"
string.split()[0] + " avg"
# Out:
# 'Temp avg'

# %%
columns = [('Temp high (°C)', 'Temp low (°C)'),
       ('Dew Point high (°C)', 'Dew Point low (°C)'),
       ('Humidity\xa0(%) high', 'Humidity\xa0(%) low'),
       ('Sea Level Press.\xa0(hPa) high', 'Sea Level Press.\xa0(hPa) low'),
       ('Visibility\xa0(km) high', 'Visibility\xa0(km) low'),
       ('Wind\xa0(km/h) low', 'Wind\xa0(km/h) high', 'Precip.\xa0(mm) sum')]

for each_set_of_column_names in columns:
  string = each_set_of_column_names[0]
  new_column_name = string.split()[0] + " avg"
  total[new_column_name] = (total[each_set_of_column_names[0]] + total[each_set_of_column_names[1]]) // 2

total.head()
# Out:
#    Year  Month  Day  Temp high (°C)  Temp low (°C)  Dew Point high (°C)  \
# 0     1      1  1.0            -3.0           -9.0                -16.0
# 1     1      1  2.0             1.0           -5.0                 -3.0
# 2     1      1  3.0             3.0           -2.0                 -5.0
# 3     1      1  4.0             6.0           -4.0                -10.0
# 4     1      1  5.0             6.0            3.0                 -1.0
#
#    Dew Point low (°C)  Humidity (%) high  Humidity (%) low  \
# 0               -19.0               54.0              32.0
# 1               -17.0               78.0              36.0
# 2               -13.0               72.0              35.0
# 3               -13.0               55.0              29.0
# 4               -16.0               62.0              33.0
#
#    Sea Level Press. (hPa) high  ...  Wind (km/h) low  Wind (km/h) high  \
# 0                       1025.0  ...             37.0              60.0
# 1                       1022.0  ...             27.0              48.0
# 2                       1018.0  ...             27.0              42.0
# 3                       1020.0  ...             32.0              40.0
# 4                       1016.0  ...             23.0              34.0
#
#    Precip. (mm) sum  WeatherEvent  Temp avg  Dew avg Humidity avg  Sea avg  \
# 0               0.0           NaN      -6.0    -18.0         43.0   1020.0
# 1               NaN          Snow      -2.0    -10.0         57.0   1014.0
# 2               NaN           NaN       0.0     -9.0         53.0   1013.0
# 3               0.0           NaN       1.0    -12.0         42.0   1017.0
# 4               NaN           NaN       4.0     -9.0         47.0   1014.0
#
#    Visibility avg  Wind avg
# 0            16.0      48.0
# 1             9.0      37.0
# 2            16.0      34.0
# 3            16.0      36.0
# 4            16.0      28.0
#
# [5 rows x 23 columns]

# %%
total.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Temp high (°C)', 'Temp low (°C)',
#        'Dew Point high (°C)', 'Dew Point low (°C)', 'Humidity (%) high',
#        'Humidity (%) low', 'Sea Level Press. (hPa) high',
#        'Sea Level Press. (hPa) low', 'Visibility (km) high',
#        'Visibility (km) low', 'Wind (km/h) low', 'Wind (km/h) high',
#        'Precip. (mm) sum', 'WeatherEvent', 'Temp avg', 'Dew avg',
#        'Humidity avg', 'Sea avg', 'Visibility avg', 'Wind avg'],
#       dtype='object')

# %%
to_be_dropped = total.columns[3:-7]
to_be_dropped
# Out:
# Index(['Temp high (°C)', 'Temp low (°C)', 'Dew Point high (°C)',
#        'Dew Point low (°C)', 'Humidity (%) high', 'Humidity (%) low',
#        'Sea Level Press. (hPa) high', 'Sea Level Press. (hPa) low',
#        'Visibility (km) high', 'Visibility (km) low', 'Wind (km/h) low',
#        'Wind (km/h) high', 'Precip. (mm) sum'],
#       dtype='object')

# %%
new_df = total.drop(columns = to_be_dropped)
new_df
# Out:
#      Year  Month   Day WeatherEvent  Temp avg  Dew avg  Humidity avg  Sea avg  \
# 0       1      1   1.0          NaN      -6.0    -18.0          43.0   1020.0
# 1       1      1   2.0         Snow      -2.0    -10.0          57.0   1014.0
# 2       1      1   3.0          NaN       0.0     -9.0          53.0   1013.0
# 3       1      1   4.0          NaN       1.0    -12.0          42.0   1017.0
# 4       1      1   5.0          NaN       4.0     -9.0          47.0   1014.0
# ..    ...    ...   ...          ...       ...      ...           ...      ...
# 361     8     12  27.0          NaN      10.0      4.0          61.0   1012.0
# 362     8     12  28.0          NaN       2.0     -5.0          54.0   1018.0
# 363     8     12  29.0         Rain       4.0      0.0          74.0   1009.0
# 364     8     12  30.0   Fog , Snow       2.0     -4.0          63.0   1007.0
# 365     8     12  31.0          NaN       3.0     -6.0          46.0   1016.0
#
#      Visibility avg  Wind avg
# 0              16.0      48.0
# 1               9.0      37.0
# 2              16.0      34.0
# 3              16.0      36.0
# 4              16.0      28.0
# ..              ...       ...
# 361            15.0      42.0
# 362            16.0      28.0
# 363             9.0      32.0
# 364             8.0      38.0
# 365            16.0      32.0
#
# [2943 rows x 10 columns]

# %%
# Generate descriptive statistics of the dataframe
new_df.describe()
# Out:
#               Year        Month          Day     Temp avg      Dew avg  \
# count  2943.000000  2943.000000  2943.000000  2941.000000  2941.000000
# mean      4.476045     6.483520    15.695889    13.042843     4.830330
# std       2.302576     3.468267     8.794056     9.750050    10.392081
# min       1.000000     1.000000     1.000000   -14.000000   -26.000000
# 25%       2.000000     3.000000     8.000000     5.000000    -3.000000
# 50%       4.000000     7.000000    16.000000    14.000000     6.000000
# 75%       6.000000     9.500000    23.000000    22.000000    14.000000
# max       8.000000    12.000000    31.000000    34.000000    23.000000
#
#        Humidity avg      Sea avg  Visibility avg     Wind avg
# count   2941.000000  2924.000000     2915.000000  2884.000000
# mean      60.956817  1015.982558       13.043911    29.381068
# std       14.414886     7.149977        3.255868     8.700198
# min       19.000000   984.000000        4.000000    10.000000
# 25%       50.000000  1011.000000        9.000000    23.000000
# 50%       60.000000  1016.000000       15.000000    28.000000
# 75%       72.000000  1021.000000       16.000000    34.000000
# max       96.000000  1040.000000       16.000000   159.000000

# %%
# Drop the duplicate rows of the dataframe
print("Before dropping duplicate rows: ", new_df.shape[0])
# Out:
# Before dropping duplicate rows:  2943

# %%
new_df.drop_duplicates(inplace=True)

# %%
print("After dropping duplicate rows: ", new_df.shape[0])
# Out:
# After dropping duplicate rows:  2922

# %%
# Normalize the data (all columns except "Year, Month, Day, WeatherEvent")
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
temp = new_df.drop(columns = ["Year", "Month", "Day", "WeatherEvent"])
normalized_df = scaler.fit_transform(temp.values)
normalized_df
# Out:
# array([[-1.97791392e+00, -2.21789911e+00, -1.24573784e+00,
#          5.61430852e-01,  9.08841070e-01,  2.14176296e+00],
#        [-1.56491296e+00, -1.44435969e+00, -2.75113201e-01,
#         -2.79339725e-01, -1.24251467e+00,  8.78005239e-01],
#        [-1.35841248e+00, -1.34766726e+00, -5.52434527e-01,
#         -4.19468155e-01,  9.08841070e-01,  5.33344042e-01],
#        ...,
#        [-9.45411526e-01, -4.77435416e-01,  9.03502430e-01,
#         -9.79981873e-01, -1.24251467e+00,  3.03569910e-01],
#        [-1.15191200e+00, -8.64205125e-01,  1.40868786e-01,
#         -1.26023873e+00, -1.54985120e+00,  9.92892305e-01],
#        [-1.04866177e+00, -1.05758998e+00, -1.03774685e+00,
#          9.17134055e-04,  9.08841070e-01,  3.03569910e-01]])

# %%
temp.head(2)
# Out:
#    Temp avg  Dew avg  Humidity avg  Sea avg  Visibility avg  Wind avg
# 0      -6.0    -18.0          43.0   1020.0            16.0      48.0
# 1      -2.0    -10.0          57.0   1014.0             9.0      37.0

# %%
norm_df = pd.DataFrame(normalized_df)
norm_df
# Out:
#              0         1         2         3         4         5
# 0    -1.977914 -2.217899 -1.245738  0.561431  0.908841  2.141763
# 1    -1.564913 -1.444360 -0.275113 -0.279340 -1.242515  0.878005
# 2    -1.358412 -1.347667 -0.552435 -0.419468  0.908841  0.533344
# 3    -1.255162 -1.637745 -1.315068  0.141046  0.908841  0.763118
# 4    -0.945412 -1.347667 -0.968417 -0.279340  0.908841 -0.155978
# ...        ...       ...       ...       ...       ...       ...
# 2917 -0.325910 -0.090666  0.002208 -0.559597  0.601505  1.452441
# 2918 -1.151912 -0.960898 -0.483104  0.281174  0.908841 -0.155978
# 2919 -0.945412 -0.477435  0.903502 -0.979982 -1.242515  0.303570
# 2920 -1.151912 -0.864205  0.140869 -1.260239 -1.549851  0.992892
# 2921 -1.048662 -1.057590 -1.037747  0.000917  0.908841  0.303570
#
# [2922 rows x 6 columns]

# %%
norm_df.columns = temp.columns

# %%
norm_df.head()
# Out:
#    Temp avg   Dew avg  Humidity avg   Sea avg  Visibility avg  Wind avg
# 0 -1.977914 -2.217899     -1.245738  0.561431        0.908841  2.141763
# 1 -1.564913 -1.444360     -0.275113 -0.279340       -1.242515  0.878005
# 2 -1.358412 -1.347667     -0.552435 -0.419468        0.908841  0.533344
# 3 -1.255162 -1.637745     -1.315068  0.141046        0.908841  0.763118
# 4 -0.945412 -1.347667     -0.968417 -0.279340        0.908841 -0.155978

# %%
new_df.shape
# Out:
# (2922, 10)

# %%
len(new_df["WeatherEvent"])
# Out:
# 2922

# %%
norm_df['Weather_event'] = list(new_df["WeatherEvent"])

# %%
norm_df.head()
# Out:
#    Temp avg   Dew avg  Humidity avg   Sea avg  Visibility avg  Wind avg  \
# 0 -1.977914 -2.217899     -1.245738  0.561431        0.908841  2.141763
# 1 -1.564913 -1.444360     -0.275113 -0.279340       -1.242515  0.878005
# 2 -1.358412 -1.347667     -0.552435 -0.419468        0.908841  0.533344
# 3 -1.255162 -1.637745     -1.315068  0.141046        0.908841  0.763118
# 4 -0.945412 -1.347667     -0.968417 -0.279340        0.908841 -0.155978
#
#   Weather_event
# 0           NaN
# 1          Snow
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# Handle NaN values
norm_df.isna().sum()
# Out:
# Temp avg             2
# Dew avg              2
# Humidity avg         2
# Sea avg             19
# Visibility avg      28
# Wind avg            59
# Weather_event     1908
# dtype: int64

# %%
norm_df.dropna(subset=["Weather_event"], inplace=True)

# %%
norm_df.fillna(0, inplace=True)

# %%
norm_df.isna().sum()
# Out:
# Temp avg          0
# Dew avg           0
# Humidity avg      0
# Sea avg           0
# Visibility avg    0
# Wind avg          0
# Weather_event     0
# dtype: int64

# %%
# Understand which year has highest "Fog,Rain,Snow"
norm_df['Weather_event'].value_counts().plot(kind = 'barh')
plt.grid(False)
plt.show()

# %%
# Correlation matrix of the dataframe
norm_df.corr()
# Out:
#                 Temp avg   Dew avg  Humidity avg   Sea avg  Visibility avg  \
# Temp avg        1.000000  0.955666      0.206933 -0.050787       -0.011156
# Dew avg         0.955666  1.000000      0.461810 -0.071074       -0.136768
# Humidity avg    0.206933  0.461810      1.000000 -0.077945       -0.483664
# Sea avg        -0.050787 -0.071074     -0.077945  1.000000        0.125017
# Visibility avg -0.011156 -0.136768     -0.483664  0.125017        1.000000
# Wind avg       -0.307610 -0.305441     -0.095846 -0.322327       -0.026611
#
#                 Wind avg
# Temp avg       -0.307610
# Dew avg        -0.305441
# Humidity avg   -0.095846
# Sea avg        -0.322327
# Visibility avg -0.026611
# Wind avg        1.000000

# %%
# Heat map
import seaborn as sns

matrix = norm_df.corr()
sns.set()
ax = sns.heatmap(matrix, annot=True)
plt.show()

# %%
# Detect Outliers
norm_df.boxplot(column = ['Humidity avg', 'Temp avg']);

# %%
# Converting the categorical data ("WeatherEvent" column) into numerical
encodes, uniques = pd.factorize(norm_df['Weather_event'])
norm_df['Weather_event'] = encodes
norm_df
# Out:
#       Temp avg   Dew avg  Humidity avg   Sea avg  Visibility avg  Wind avg  \
# 1    -1.564913 -1.444360     -0.275113 -0.279340       -1.242515  0.878005
# 5    -1.255162 -1.444360     -0.552435 -0.279340       -0.627842 -0.385752
# 6    -1.255162 -0.477435      2.012788 -2.661523       -1.242515  1.911989
# 9    -1.668163 -1.250975      0.556851  0.421302       -1.549851  0.303570
# 10   -1.668163 -1.057590      1.111493 -0.699725       -0.935178  0.303570
# ...        ...       ...           ...       ...             ...       ...
# 2908 -0.738911 -0.380743      0.626181  0.281174       -1.549851  1.107779
# 2914 -0.842161 -0.477435      0.626181  0.981816       -1.242515 -0.041091
# 2916 -0.842161 -0.477435      0.626181  1.962715       -0.935178  0.188683
# 2919 -0.945412 -0.477435      0.903502 -0.979982       -1.242515  0.303570
# 2920 -1.151912 -0.864205      0.140869 -1.260239       -1.549851  0.992892
#
#       Weather_event
# 1                 0
# 5                 1
# 6                 1
# 9                 2
# 10                1
# ...             ...
# 2908              6
# 2914              1
# 2916              1
# 2919              1
# 2920              3
#
# [1014 rows x 7 columns]
